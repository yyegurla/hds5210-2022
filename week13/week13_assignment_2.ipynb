# %% [markdown]
# # Week 13 Programming Assignment
#
# As you're working on identifying data for your final project, it's helpful to spend some time exploring your various data files.  For this week's assignment, I'd like you to take a few of the ideas from the the lectures, review assignment, and tonight's lecture to start exploring the data you plan to use for the final project.
#
# For the following activities, you can use just one of the data files that you've identified, or you can do the activities using different data files.  That's up to you.  Please describe what you're doing in a Markdown cell or in the comments of your code.  When you've completed the assignment, submit it as normal.

# %% [markdown]
# ### 1. Basic Statistics
#
# Use Python to read in your data file and show many rows and columns your data has.

# %%
import pandas as pd
df = pd.read_csv("U.S._Chronic_Disease_Indicators__CDI_.csv", low_memory=False)
df.shape
# Out:
# (1048575, 34)

# %% [markdown]
# ### 2. Data Diversity
#
# Use Python to identify how many unique values each column in your data has.  Use Python to identify which column has the greatest number of distinct values (aka the most diversity)?  If your data has a unique identifier (e.g. a person or visit or record ID) then find the column with the next most number of unique values.

# %%
columns =df.columns
print(columns )
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %%
list = []
for i in columns:
    print(f"{i}", '\t', len(df[i].unique()))
    list.append(len(df[i].unique()))
print("The column which has greatest distinct values is:", max(list))
# Out:
# YearStart 	 16
# YearEnd 	 16
# LocationAbbr 	 55
# LocationDesc 	 55
# DataSource 	 31
# Topic 	 17
# Question 	 203
# Response 	 1
# DataValueUnit 	 13
# DataValueType 	 19
# DataValue 	 39844
# DataValueAlt 	 39832
# DataValueFootnoteSymbol 	 18
# DatavalueFootnote 	 19
# LowConfidenceLimit 	 21945
# HighConfidenceLimit 	 23474
# StratificationCategory1 	 3
# Stratification1 	 11
# StratificationCategory2 	 1
# Stratification2 	 1
# StratificationCategory3 	 1
# Stratification3 	 1
# GeoLocation 	 55
# ResponseID 	 1
# LocationID 	 55
# TopicID 	 17
# QuestionID 	 203
# DataValueTypeID 	 19
# StratificationCategoryID1 	 3
# StratificationID1 	 13
# StratificationCategoryID2 	 1
# StratificationID2 	 1
# StratificationCategoryID3 	 1
# StratificationID3 	 1
# The column which has greatest distinct values is: 39844

# %% [markdown]
# ### 3. Data Redundancy
#
# Use Python to identify any columns in your data where the value for every row is the same.  For example, if you had a gender column and all the rows said 'M', then you would want to write the code that helped you determine that.

# %%
for i in columns:
    print(df[i].duplicated())
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: YearStart, Length: 1048575, dtype: bool
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: YearEnd, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: LocationAbbr, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: LocationDesc, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: DataSource, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3          False
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: Topic, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3          False
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: Question, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: Response, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: DataValueUnit, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: DataValueType, Length: 1048575, dtype: bool
# 0          False
# 1          False
# 2           True
# 3          False
# 4          False
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: DataValue, Length: 1048575, dtype: bool
# 0          False
# 1          False
# 2           True
# 3          False
# 4          False
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: DataValueAlt, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: DataValueFootnoteSymbol, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: DatavalueFootnote, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: LowConfidenceLimit, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: HighConfidenceLimit, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3          False
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: StratificationCategory1, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3          False
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: Stratification1, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: StratificationCategory2, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: Stratification2, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: StratificationCategory3, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: Stratification3, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: GeoLocation, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: ResponseID, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: LocationID, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3          False
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: TopicID, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3          False
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: QuestionID, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: DataValueTypeID, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3          False
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: StratificationCategoryID1, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3          False
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: StratificationID1, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: StratificationCategoryID2, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: StratificationID2, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: StratificationCategoryID3, Length: 1048575, dtype: bool
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: StratificationID3, Length: 1048575, dtype: bool

# %% [markdown]
# ### 4. Range of Values
#
# Your data almost certainly has some numeric columns that can be summed or averaged.  Create a histogram that shows the distribution of values for this column.

# %%
import matplotlib
import matplotlib.pyplot as plt
df[['HighConfidenceLimit','LowConfidenceLimit']].hist(figsize=(11,5.5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7effcce2cd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7effcad8d0f0>]],
#       dtype=object)

# %% [markdown]
# ### 5. Discussion
#
# Do any additional exploration of this data that you think may be interesting and include your code here.  Then go onto Slack and make a post about what you've observed.  Share your observation.  Share your code, if you like.  Share a screenshot of the data or a chart based on the data.
#
# Then comment on at least two other people's observations that they share on Slack.  (Use the reply as thread option in Slack to keep the conversation organized.)

# %%
import matplotlib
import matplotlib.pyplot as plt
df['YearStart'].hist(figsize=(11,5.5))

# %% [markdown]
# ---
#
#
#
# ## Submitting Your Work
#
# Submit your work as usual.
